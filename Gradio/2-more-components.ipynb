# %% [markdown]
# <p style="color:#153462;
#           font-weight: bold;
#           font-size: 30px;
#           font-family: Gill Sans, sans-serif;
#           text-align: center;">
# Gradio Components</p>

# %% [markdown]
# <p style="text-align: justify; text-justify: inter-word; font-size:17px;">
#   In this document, we cover some important Gradio components with use for taking input and sending or showing output. We can use similar components for both input and output. For example, you can use <code>gradio.Textbox</code> for taking text input and you can even use it for showing text output.
# </p>

# %%
import gradio as gr
from rembg import remove
from PIL import Image

# %% [markdown]
# ### <span style="color:#123524;  font-weight: bold;">gradio.Textbox(···)</span>

# %% [markdown]
# <p style="text-align: justify; text-justify: inter-word; font-size:17px;">
#   Creates a textarea for user to enter string input or display string output.
# </p>

# %%
def authenticate(username: str | None, email: str | None, password: str):
    secrete_msg = ""
    if password == "open":
        secrete_msg = "Welcome to Gradio!!!"
    return username, email, secrete_msg

# %%
iface = gr.Interface(fn=authenticate,
                     inputs = [gr.Textbox(placeholder="Enter your username"),
                               gr.Textbox(placeholder="Enter your email", type="email"),
                               gr.Textbox(placeholder="Enter your password", type="password")],
                     outputs = [gr.Textbox(label="Username"), gr.Textbox(label="Email"), gr.TextArea()])
iface.launch()

# %% [markdown]
# ### <span style="color:#123524;  font-weight: bold;">Slider</span>

# %%
def volume(count):
    return f"Selected size is: {count}"

iface = gr.Interface(fn = volume,
                     inputs = gr.Slider(minimum=0, maximum=100, step=2),
                     outputs = gr.Text())
iface.launch()

# %% [markdown]
# ### <span style="color:#123524;  font-weight: bold;">Dropdown, CheckboxGroup, Radio, Dropdown, Checkbox</span>

# %%
def sentence_builder(quantity, animal, countries, place, activity_list, morning):
    return f"""The {quantity} {animal}s from {" and ".join(countries)} \
               went to the {place} where they {" and ".join(activity_list)} \
               until the {"morning" if morning else "night"}"""

demo = gr.Interface(fn=sentence_builder,
                    inputs = [gr.Slider(2, 20, value=4, label="Count", info="Choose between 2 and 20"),
                              gr.Dropdown(["cat", "dog", "bird"], 
                                          label="Animal", 
                                          info="Will add more animals later!"),
                              gr.CheckboxGroup(["USA", "Japan", "Pakistan"],
                                               label="Countries",
                                               info="Where are they from?"),
                              gr.Radio(["park", "zoo", "road"], 
                                       label="Location",
                                       info="Where did they go?"),
                              gr.Dropdown(["ran", "swam", "ate", "slept"],
                                          value=["swam", "slept"], 
                                          multiselect=True, 
                                          label="Activity"),
                              gr.Checkbox(label="Morning", info="Did they do it in the morning?"),
                            ],
                    outputs="text",
                    examples=[
                        [2, "cat", ["Japan", "Pakistan"], "park", ["ate", "swam"], True],
                        [4, "dog", ["Japan"], "zoo", ["ate", "swam"], False],
                        [10, "bird", ["USA", "Pakistan"], "road", ["ran"], False],
                        [8, "cat", ["Pakistan"], "zoo", ["ate"], True],
                    ]
                 )
demo.launch()

# %% [markdown]
# ### <span style="color:#123524;  font-weight: bold;">gradio.Image</span>

# %%
def background_remover(img_path: str):
    image = Image.open(img_path)
    return remove(image)

# %%
sys.platform
# Out:
# 'win32'

# %%
iface = gr.Interface(fn=background_remover,
                     inputs=gr.Image(type="filepath"),
                     outputs=gr.Image())


iface.launch(show_error=True, debug=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 403, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.scope, self.receive, self.send
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\fastapi\applications.py", line 1134, in __call__
#     await super().__call__(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\gradio\route_utils.py", line 882, in __call__
#     await self.app(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\fastapi\routing.py", line 125, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\fastapi\routing.py", line 111, in app
#     response = await f(request)
#                ^^^^^^^^^^^^^^^^
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\fastapi\routing.py", line 391, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#     )
#     ^
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\fastapi\routing.py", line 290, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\gradio\routes.py", line 1671, in get_upload_progress
#     await asyncio.wait_for(
#         file_upload_statuses.is_tracked(upload_id), timeout=3
#     )
#   File "C:\Users\madhubabukencha\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "D:\Artificial_Intelligence\ui-for-ai\ui-for-ai-venv\Lib\site-packages\gradio\route_utils.py", line 528, in is_tracked
#     return await self._signals[upload_id].wait()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\madhubabukencha\AppData\Local\Programs\Python\Python313\Lib\asyncio\locks.py", line 210, in wait
#     fut = self._get_loop().create_future()
#           ~~~~~~~~~~~~~~^^
#   File "C:\Users\madhubabukencha\AppData\Local\Programs\Python\Python313\Lib\asyncio\mixins.py", line 20, in _get_loop
#     raise RuntimeError(f'{self!r} is bound to a different event loop')
# RuntimeError: <asyncio.locks.Event object at 0x0000024800F4DA30 [unset]> is bound to a different event loop
